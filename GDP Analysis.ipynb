# %% [markdown]
# # Part 1 A

# %%
import pandas as pd

# %%
import numpy as np

# %%
#Read dataset
mf = pd.read_csv(r'C:\Users\Ashish Pandey\Downloads\Part I-A.csv')

# %%
mf
# Out:
#                     Items  Description Duration  Andhra Pradesh   \
# 0   GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1   GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2   GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3   GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4   GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 5   GSDP - CURRENT PRICES (` in Crore)  2016-17        699307.00
# 6        (% Growth over previous year)  2012-13             8.43
# 7        (% Growth over previous year)  2013-14            12.85
# 8        (% Growth over previous year)  2014-15            13.40
# 9        (% Growth over previous year)  2015-16            15.85
# 10       (% Growth over previous year)  2016-17            14.65
#
#     Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa  \
# 0            11063.00  143175.00  247144.00     158074.00  42367.00
# ...

# %%
#Dropping 5th and 10th indices
mf1=mf.drop(mf.index[[5,10]])

# %%
#splitting df into two 
mf_1=mf1.loc[mf['Items  Description']=='GSDP - CURRENT PRICES (` in Crore)']
mf_2=mf1.loc[mf['Items  Description']=='(% Growth over previous year)']

# %%
#Replacing Mean by nan
mf_1.loc[np.isnan(mf['Himachal Pradesh']), ['Himachal Pradesh']] = mf_1['Himachal Pradesh'].mean()
mf_1.loc[np.isnan(mf['Maharashtra']), ['Maharashtra']] = mf_1['Maharashtra'].mean()
mf_1.loc[np.isnan(mf['Manipur']), ['Manipur']] = mf_1['Manipur'].mean()
mf_1.loc[np.isnan(mf['Mizoram']), ['Mizoram']] = mf_1['Mizoram'].mean()
mf_1.loc[np.isnan(mf['Nagaland']), ['Nagaland']] = mf_1['Nagaland'].mean()
mf_1.loc[np.isnan(mf['Punjab']), ['Punjab']] = mf_1['Punjab'].mean()
mf_1.loc[np.isnan(mf['Rajasthan']), ['Rajasthan']] = mf_1['Rajasthan'].mean()
mf_1.loc[np.isnan(mf['Tripura']), ['Tripura']] = mf_1['Tripura'].mean()
mf_1.loc[np.isnan(mf['Andaman & Nicobar Islands']), ['Andaman & Nicobar Islands']] = mf_1['Andaman & Nicobar Islands'].mean()
mf_2.loc[np.isnan(mf['Himachal Pradesh']), ['Himachal Pradesh']] = mf_2['Himachal Pradesh'].mean()
mf_2.loc[np.isnan(mf['Maharashtra']), ['Maharashtra']] = mf_2['Maharashtra'].mean()
mf_2.loc[np.isnan(mf['Manipur']), ['Manipur']] = mf_2['Manipur'].mean()
mf_2.loc[np.isnan(mf['Mizoram']), ['Mizoram']] = mf_2['Mizoram'].mean()
mf_2.loc[np.isnan(mf['Nagaland']), ['Nagaland']] = mf_2['Nagaland'].mean()
mf_2.loc[np.isnan(mf['Punjab']), ['Punjab']] = mf_2['Punjab'].mean()
mf_2.loc[np.isnan(mf['Rajasthan']), ['Rajasthan']] = mf_2['Rajasthan'].mean()
mf_2.loc[np.isnan(mf['Tripura']), ['Tripura']] = mf_2['Tripura'].mean()
mf_2.loc[np.isnan(mf['Andaman & Nicobar Islands']), ['Andaman & Nicobar Islands']] = mf_2['Andaman & Nicobar Islands'].mean()
# Out:
# C:\Users\Ashish Pandey\Anaconda3\lib\site-packages\pandas\core\indexing.py:543: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s

# %%
#concatenating
mf_3=pd.concat([mf_1, mf_2], axis=0, sort=False)
print(mf_3)
# Out:
#                    Items  Description Duration  Andhra Pradesh   \
# 0  GSDP - CURRENT PRICES (` in Crore)  2011-12        379402.00
# 1  GSDP - CURRENT PRICES (` in Crore)  2012-13        411404.00
# 2  GSDP - CURRENT PRICES (` in Crore)  2013-14        464272.00
# 3  GSDP - CURRENT PRICES (` in Crore)  2014-15        526468.00
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16        609934.00
# 6       (% Growth over previous year)  2012-13             8.43
# 7       (% Growth over previous year)  2013-14            12.85
# 8       (% Growth over previous year)  2014-15            13.40
# 9       (% Growth over previous year)  2015-16            15.85
#
#    Arunachal Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 0           11063.00  143175.00  247144.00     158074.00  42367.00  615606.00
# 1           12547.00  156864.00  282368.00     177511.00  38120.00  724495.00
# 2           14602.00  177745.00  317101.00     206690.00  35921.00  807623.00
# ...

# %%
#Making duration Index
mf_2.set_index(['Duration'],inplace = True)

# %%
mf1=mf_2.T

# %%
#Dropping 2012-13 column
mf1.drop(['2012-13'], axis=1)
# Out:
# Duration                                         2013-14  \
# Items  Description         (% Growth over previous year)
# Andhra Pradesh                                     12.85
# Arunachal Pradesh                                  16.38
# Assam                                              13.31
# Bihar                                               12.3
# Chhattisgarh                                       16.44
# Goa                                                -5.77
# Gujarat                                            11.47
# Haryana                                            15.45
# Himachal Pradesh                                   14.42
# Jammu & Kashmir                                    10.09
# Jharkhand                                           7.92
# Karnataka                                          18.24
# Kerala                                             12.79
# Madhya Pradesh                                     14.91
# ...

# %%
#Dropping Items Description
mf1.drop(['Items  Description'], inplace = True)

# %%
#Dropping 2012-13 column
mf1.drop(['2012-13'], axis=1, inplace=True)

# %%
mf1.drop('West Bengal1',0,inplace=True)

# %%
mf1['Average']=mf1.mean(axis=1)

# %%
mf1.reset_index(inplace=True)

# %%
mf1['2013-14']=pd.to_numeric(mf1['2013-14'], errors='coerce')

mf1['2014-15']=pd.to_numeric(mf1['2014-15'], errors='coerce')

mf1['2015-16']=pd.to_numeric(mf1['2015-16'], errors='coerce')

# %%
mf1.sort_values('Average',ascending=False,inplace=True)

# %%
mf1.reset_index(inplace=True)

# %%
mf1.drop('level_0',axis=1,inplace=True)

# %%
mf1 = mf1.rename(columns={'index': 'States'})
print(mf1)
# Out:
# Duration                     States  2013-14  2014-15    2015-16    Average
# 0                           Mizoram    23.10    12.30  16.866667  17.422222
# 1                           Tripura    18.14    15.92  15.613333  16.557778
# 2                          Nagaland    21.98    10.85  15.953333  16.261111
# 3                 Arunachal Pradesh    16.38    14.79  12.070000  14.413333
# 4                         Karnataka    18.24    12.70  11.420000  14.120000
# 5                   Andhra Pradesh     12.85    13.40  15.850000  14.033333
# 6                      Chhattisgarh    16.44    13.69  10.980000  13.703333
# 7                           Manipur    17.83    11.39  11.890000  13.703333
# 8                             Bihar    12.30    17.92  10.590000  13.603333
# 9         Andaman & Nicobar Islands    16.68    10.89  12.900000  13.490000
# 10                        Telangana    12.63    13.05  12.610000  12.763333
# ...

# %%
mf1.drop(26,0,inplace=True)

# %%
mf1
# Out:
# Duration                     States  2013-14  2014-15    2015-16    Average
# 0                           Mizoram    23.10    12.30  16.866667  17.422222
# 1                           Tripura    18.14    15.92  15.613333  16.557778
# 2                          Nagaland    21.98    10.85  15.953333  16.261111
# 3                 Arunachal Pradesh    16.38    14.79  12.070000  14.413333
# 4                         Karnataka    18.24    12.70  11.420000  14.120000
# 5                   Andhra Pradesh     12.85    13.40  15.850000  14.033333
# 6                      Chhattisgarh    16.44    13.69  10.980000  13.703333
# 7                           Manipur    17.83    11.39  11.890000  13.703333
# 8                             Bihar    12.30    17.92  10.590000  13.603333
# 9         Andaman & Nicobar Islands    16.68    10.89  12.900000  13.490000
# 10                        Telangana    12.63    13.05  12.610000  12.763333
# ...

# %%
import matplotlib.pyplot as plt

import seaborn as sns

# %%
sns.set(style='whitegrid')
plt.figure(figsize=(20,15))
sns.barplot(x=mf1.Average, y=mf1.States, data=mf1)
plt.xlabel("Average Growth Rate %", fontsize=18)
plt.ylabel("States", fontsize=18)
plt.title("Avg. Growth Rate Of Various States", fontsize=18)

plt.show()

# %%
#Which states have been growing consistently fast, and which ones have been struggling?
print("State which has been growing consitently fast :\n",mf1.iloc[0,:3])
print("State which has been struggling consitently:\n",mf1.iloc[-1,:])
# Out:
# State which has been growing consitently fast :
#  Duration
# States     Mizoram
# 2013-14       23.1
# 2014-15       12.3
# Name: 0, dtype: object
# State which has been struggling consitently:
#  Duration
# States         Goa
# 2013-14      -5.77
# 2014-15      13.12
# 2015-16      10.75
# Average    6.03333
# Name: 32, dtype: object

# %%
mf1.sort_values(by="2015-16",ascending=False,inplace=True)

# %%
#Plot the total GDP of the states for the year 2015-16:

sns.set(style='whitegrid')
plt.figure(figsize=(20,15))
sns.barplot(x=mf1['2015-16'], y=mf1.States, data=mf1)
plt.xlabel("Total GDP", fontsize=18)
plt.ylabel("States", fontsize=18)
plt.title("Total GDP of the states for the year 2015-16", fontsize=18)
# Out:
# Text(0.5, 1.0, 'Total GDP of the states for the year 2015-16')

# %% [markdown]
# # Part 1 B

# %%
import numpy as np

# %%
import pandas as pd

# %%
import os

# %%
import pandas as pd

# %%
import glob

# %%
cwd=r'C:\Users\Ashish Pandey\Downloads'

# %%
dirs = os.listdir( cwd )

# %%
dfq=[]

# %%
for items in dirs:
    if items.find('GSVA')>0 and items.find('.csv')>0:
        x=cwd+'\\'+items
        temp_df=pd.read_csv((x),encoding = "ISO-8859-1")
        temp_df=temp_df.loc[::,['S.No.','Item','2014-15']]
        temp_df['State']=items.split('-')[1]
        dfq.append(temp_df)
df=pd.concat(dfq)

# %%
df=pd.concat(dfq)

# %%
df
# Out:
#     S.No.                                               Item      2014-15  \
# 0       1                  Agriculture, forestry and fishing   14819416.0
# 1     1.1                                              Crops    7893514.0
# 2     1.2                                          Livestock    4309078.0
# 3     1.3                               Forestry and logging     346160.0
# 4     1.4                            Fishing and aquaculture    2270664.0
# 5       2                               Mining and quarrying    1484300.0
# 6   Total                                            Primary   16303716.0
# 7       3                                      Manufacturing    4672266.0
# 8       4  Electricity, gas, water supply & other utility...    1151729.0
# 9       5                                       Construction    4664889.0
# 10  Total                                          Secondary   10488884.0
# 11      6              Trade, repair, hotels and restaurants    4233400.0
# ...

# %%
df.set_index('State',inplace=True)
df.transpose()
# Out:
# State                       Andhra_Pradesh Andhra_Pradesh Andhra_Pradesh  \
# S.No.                                    1            1.1            1.2
# Item     Agriculture, forestry and fishing          Crops      Livestock
# 2014-15                        1.48194e+07    7.89351e+06    4.30908e+06
#
# State          Andhra_Pradesh           Andhra_Pradesh        Andhra_Pradesh  \
# S.No.                     1.3                      1.4                     2
# Item     Forestry and logging  Fishing and aquaculture  Mining and quarrying
# 2014-15                346160              2.27066e+06            1.4843e+06
#
# State   Andhra_Pradesh Andhra_Pradesh  \
# S.No.            Total              3
# Item           Primary  Manufacturing
# 2014-15    1.63037e+07    4.67227e+06
#
# State                                       Andhra_Pradesh Andhra_Pradesh  \
# S.No.                                                    4              5
# ...

# %%
#Remove UTs
df=df.drop('Delhi',axis=0)
df=df.drop('Chandigarh',axis=0)
df=df.drop('Puducherry',axis=0)

# %%
df
# Out:
#                 S.No.                                               Item  \
# State
# Andhra_Pradesh      1                  Agriculture, forestry and fishing
# Andhra_Pradesh    1.1                                              Crops
# Andhra_Pradesh    1.2                                          Livestock
# Andhra_Pradesh    1.3                               Forestry and logging
# Andhra_Pradesh    1.4                            Fishing and aquaculture
# Andhra_Pradesh      2                               Mining and quarrying
# Andhra_Pradesh  Total                                            Primary
# Andhra_Pradesh      3                                      Manufacturing
# Andhra_Pradesh      4  Electricity, gas, water supply & other utility...
# Andhra_Pradesh      5                                       Construction
# Andhra_Pradesh  Total                                          Secondary
# Andhra_Pradesh      6              Trade, repair, hotels and restaurants
# ...

# %%
#Filter the GDP per capita for all the states.

df_gdp_per_cap = df.loc[df.Item=='Per Capita GSDP (Rs.)']

# %%
df_gdp_per_cap
# Out:
#                   S.No.                   Item   2014-15
# State
# Andhra_Pradesh       17  Per Capita GSDP (Rs.)  104977.0
# Arunachal_Pradesh    17  Per Capita GSDP (Rs.)  112718.0
# Arunachal_Pradesh    17  Per Capita GSDP (Rs.)  112718.0
# Assam                17  Per Capita GSDP (Rs.)   60621.0
# Bihar                17  Per Capita GSDP (Rs.)   33954.0
# Chhattisgarh         17  Per Capita GSDP (Rs.)   86860.0
# Goa                  17  Per Capita GSDP (Rs.)  271793.0
# Gujarat              17  Per Capita GSDP (Rs.)  141263.0
# Haryana              17  Per Capita GSDP (Rs.)  164077.0
# Himachal_Pradesh     17  Per Capita GSDP (Rs.)  147330.0
# Jharkhand            17  Per Capita GSDP (Rs.)   62091.0
# Karnataka            17  Per Capita GSDP (Rs.)  145141.0
# Kerala               17  Per Capita GSDP (Rs.)  154778.0
# Madhya_Pradesh       17  Per Capita GSDP (Rs.)   62989.0
# Maharashtra          17  Per Capita GSDP (Rs.)  152853.0
# ...

# %%
df_gdp_per_cap.sort_values(by="2014-15", ascending = False, inplace=True)
# Out:
# C:\Users\Ashish Pandey\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df_gdp_per_cap
# Out:
#                   S.No.                   Item   2014-15
# State
# Goa                  17  Per Capita GSDP (Rs.)  271793.0
# Sikkim               17  Per Capita GSDP (Rs.)  240274.0
# Haryana              17  Per Capita GSDP (Rs.)  164077.0
# Kerala               17  Per Capita GSDP (Rs.)  154778.0
# Uttarakhand          17  Per Capita GSDP (Rs.)  153076.0
# Maharashtra          17  Per Capita GSDP (Rs.)  152853.0
# Himachal_Pradesh     17  Per Capita GSDP (Rs.)  147330.0
# Tamil_Nadu           17  Per Capita GSDP (Rs.)  146503.0
# Karnataka            17  Per Capita GSDP (Rs.)  145141.0
# Gujarat              17  Per Capita GSDP (Rs.)  141263.0
# Telangana            17  Per Capita GSDP (Rs.)  139035.0
# Punjab               17  Per Capita GSDP (Rs.)  126606.0
# Arunachal_Pradesh    17  Per Capita GSDP (Rs.)  112718.0
# Arunachal_Pradesh    17  Per Capita GSDP (Rs.)  112718.0
# Andhra_Pradesh       17  Per Capita GSDP (Rs.)  104977.0
# ...

# %%
#Removing duplicates
df_gdp_per_cap.drop_duplicates(keep = 'first', inplace = True)
# Out:
# C:\Users\Ashish Pandey\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_gdp_per_cap
# Out:
#                   S.No.                   Item   2014-15
# State
# Goa                  17  Per Capita GSDP (Rs.)  271793.0
# Sikkim               17  Per Capita GSDP (Rs.)  240274.0
# Haryana              17  Per Capita GSDP (Rs.)  164077.0
# Kerala               17  Per Capita GSDP (Rs.)  154778.0
# Uttarakhand          17  Per Capita GSDP (Rs.)  153076.0
# Maharashtra          17  Per Capita GSDP (Rs.)  152853.0
# Himachal_Pradesh     17  Per Capita GSDP (Rs.)  147330.0
# Tamil_Nadu           17  Per Capita GSDP (Rs.)  146503.0
# Karnataka            17  Per Capita GSDP (Rs.)  145141.0
# Gujarat              17  Per Capita GSDP (Rs.)  141263.0
# Telangana            17  Per Capita GSDP (Rs.)  139035.0
# Punjab               17  Per Capita GSDP (Rs.)  126606.0
# Arunachal_Pradesh    17  Per Capita GSDP (Rs.)  112718.0
# Andhra_Pradesh       17  Per Capita GSDP (Rs.)  104977.0
# Mizoram              17  Per Capita GSDP (Rs.)   97687.0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#plot GDP per capita for each state
sns.set(style='whitegrid')
plt.figure(figsize=(20,15))
sns.barplot(x=df_gdp_per_cap['2014-15'], y=df_gdp_per_cap.index, data=df_gdp_per_cap)
plt.xlabel("GDP Per Capita %", fontsize=18)
plt.ylabel("States", fontsize=18)
plt.title("GDP per capita for all the states for the year 2014-15", fontsize=18)
plt.show()

# %%
#Find the ratio of highest per capita GDP to the lowest per capita GDP.
("ratio of highest per capita GDP to the lowest per capita GDP is ",int(df_gsdp_per_cap.iloc[0,2]/df_gsdp_per_cap.iloc[-1,2]),':1')
# Out:
# ('ratio of highest per capita GDP to the lowest per capita GDP is ', 8, ':1')

# %%
#Identify the top-5 and the bottom-5 states based on GDP per capita.

print("Top 5 States based on GDP per capita:\n",df_gdp_per_cap.iloc[0:5,2])
print("Bottom 5 States based on GDP per capita:\n",df_gdp_per_cap.iloc[-5:,2])
# Out:
# Top 5 States based on GDP per capita:
#  State
# Goa            271793.0
# Sikkim         240274.0
# Haryana        164077.0
# Kerala         154778.0
# Uttarakhand    153076.0
# Name: 2014-15, dtype: float64
# Bottom 5 States based on GDP per capita:
#  State
# Jharkhand        62091.0
# Assam            60621.0
# Manipur          58442.0
# Uttar_Pradesh    49450.0
# Bihar            33954.0
# Name: 2014-15, dtype: float64

# %%
#Filter primary,seconday and tertiary sectors as % of total GDP for all the states.
df_GDP = df.loc[(df.Item=='Primary') | (df.Item=='Secondary') | (df.Item=='Tertiary')]
df5=pd.pivot_table(df_GDP,index=['State'],columns='Item',values="2014-15")
df5
# Out:
# Item                  Primary   Secondary    Tertiary
# State
# Andhra_Pradesh     16303716.0  10488884.0  22032942.0
# Arunachal_Pradesh    716959.0    287489.0    631844.0
# Assam               5326697.0   4033091.0   9307109.0
# Bihar               8019997.0   5984896.0  22179969.0
# Chhattisgarh        6400817.0   8238886.0   7588778.0
# Goa                  312129.0   1547536.0   1738217.0
# Gujarat            15887187.0  33023538.0  30220377.0
# Haryana             8040424.0  12561411.0  19226568.0
# Himachal_Pradesh    1548366.0   4119162.0   4133326.0
# Jharkhand           5248354.0   6241471.0   8133341.0
# Karnataka          12066304.0  20484404.0  50490630.0
# Kerala              6489442.0  12070040.0  29673778.0
# Madhya_Pradesh     17854020.0  10044889.0  18117360.0
# Maharashtra        21758383.0  47445207.0  88631076.0
# Manipur              383140.0    220173.0   1177334.0
# Meghalaya            451050.0    637942.0   1200655.0
# ...

# %%
#Plot the percentage contribution of primary,seconday and tertiary as percentage of total GDP of all the states
sns.set(style='whitegrid')
plt.figure(figsize=(30,15))
df5.plot(kind='bar',figsize=(15,8),stacked=True)
plt.title("percentage contribution of primary,seconday and tertiary as percentage of total GDP of all the states")
plt.show()

# %%
#Categorise the states into four categories based on GDP per capita (C1, C2, C3, C4 - C1 would have the highest per capita GDP, C4 the lowest)
df_gdp_per_cap['Quantile']=pd.qcut(df_gdp_per_cap['2014-15'],[0.0,.2,.5,.85,1], labels=["c4","c3","c2","c1"])
# Out:
# C:\Users\Ashish Pandey\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Out:
#    S.No.                   Item   2014-15              State Quantile
# 32    17  Per Capita GSDP (Rs.)  271793.0                Goa       c1
# 32    17  Per Capita GSDP (Rs.)  240274.0             Sikkim       c1
# 32    17  Per Capita GSDP (Rs.)  164077.0            Haryana       c1
# 32    17  Per Capita GSDP (Rs.)  154778.0             Kerala       c1
# 32    17  Per Capita GSDP (Rs.)  153076.0        Uttarakhand       c1
# 32    17  Per Capita GSDP (Rs.)  152853.0        Maharashtra       c2
# 32    17  Per Capita GSDP (Rs.)  147330.0   Himachal_Pradesh       c2
# 32    17  Per Capita GSDP (Rs.)  146503.0         Tamil_Nadu       c2
# 32    17  Per Capita GSDP (Rs.)  145141.0          Karnataka       c2
# 32    17  Per Capita GSDP (Rs.)  141263.0            Gujarat       c2
# 32    17  Per Capita GSDP (Rs.)  139035.0          Telangana       c2
# 32    17  Per Capita GSDP (Rs.)  126606.0             Punjab       c2
# ...

# %%
df
# Out:
#     S.No.                                               Item      2014-15  \
# 0       1                  Agriculture, forestry and fishing   14819416.0
# 1     1.1                                              Crops    7893514.0
# 2     1.2                                          Livestock    4309078.0
# 3     1.3                               Forestry and logging     346160.0
# 4     1.4                            Fishing and aquaculture    2270664.0
# 5       2                               Mining and quarrying    1484300.0
# 6   Total                                            Primary   16303716.0
# 7       3                                      Manufacturing    4672266.0
# 8       4  Electricity, gas, water supply & other utility...    1151729.0
# 9       5                                       Construction    4664889.0
# 10  Total                                          Secondary   10488884.0
# 11      6              Trade, repair, hotels and restaurants    4233400.0
# ...

# %%
gf=df_gdp_per_cap.loc[df_gdp_per_cap['Quantile']=='c1']

# %%
gf
# Out:
#         S.No.                   Item   2014-15 Quantile
# State
# Goa        17  Per Capita GSDP (Rs.)  271793.0       c1
# Sikkim     17  Per Capita GSDP (Rs.)  240274.0       c1
# Haryana    17  Per Capita GSDP (Rs.)  164077.0       c1
# Kerala     17  Per Capita GSDP (Rs.)  154778.0       c1

# %%
gf1=pd.merge(df_gdp_per_cap,df,how='inner',on='State')

# %%
gf1
# Out:
#       S.No._x                 Item_x  2014-15_x Quantile S.No._y  \
# State
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       1
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.1
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.2
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.3
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.4
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       2
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1   Total
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       3
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       4
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       5
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1   Total
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       6
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     6.1
# ...

# %%
gf1.rename(columns={'Item_y':'Sub Sectors'},inplace=True)
gf1
# Out:
#       S.No._x                 Item_x  2014-15_x Quantile S.No._y  \
# State
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       1
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.1
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.2
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.3
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     1.4
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       2
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1   Total
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       3
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       4
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       5
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1   Total
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1       6
# Goa        17  Per Capita GSDP (Rs.)   271793.0       c1     6.1
# ...

# %%
gf1_c1=gf1.loc[gf1.Quantile=='c1']

# %%
gf1_c1
# Out:
#        S.No._x                 Item_x  2014-15_x Quantile S.No._y  \
# State
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1       1
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1     1.1
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1     1.2
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1     1.3
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1     1.4
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1       2
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1   Total
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1       3
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1       4
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1       5
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1   Total
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1       6
# Goa         17  Per Capita GSDP (Rs.)   271793.0       c1     6.1
# ...

# %%
gf1_c11=gf1_c1.groupby('Sub Sectors').agg('sum')

# %%
gf1_c11['Average']=(gf1_c11['2014-15_y']/101930677*100)
gf1_c11.sort_values('Average',ascending=False,inplace=True)
gf1_c11
# Out:
#                                                     2014-15_x    2014-15_y  \
# Sub Sectors
# Gross State Domestic Product                         830922.0  101930677.0
# TOTAL GSVA at basic prices                           830922.0   93126678.0
# Tertiary                                             830922.0   51121666.0
# Secondary                                            830922.0   27024240.0
# Primary                                              830922.0   14980771.0
# Real estate, ownership of dwelling & profession...   830922.0   14740245.0
# Agriculture, forestry and fishing                    830922.0   14391809.0
# Trade, repair, hotels and restaurants                830922.0   13995159.0
# Manufacturing                                        830922.0   13758793.0
# Construction                                         830922.0   11264451.0
# Taxes on Products                                    830922.0   10774501.0
# ...

# %%
gf1_c11=gf1_c11.drop('Gross State Domestic Product',axis=0)

# %%
gf1_c11=gf1_c11.drop('TOTAL GSVA at basic prices',axis=0)

# %%
gf1_c11=gf1_c11.drop('Tertiary',axis=0)

# %%
gf1_c11=gf1_c11.drop('Secondary',axis=0)
gf1_c11=gf1_c11.drop('Primary',axis=0)
gf1_c11
# Out:
#                                                     2014-15_x   2014-15_y  \
# Sub Sectors
# Real estate, ownership of dwelling & profession...   830922.0  14740245.0
# Agriculture, forestry and fishing                    830922.0  14391809.0
# Trade, repair, hotels and restaurants                830922.0  13995159.0
# Manufacturing                                        830922.0  13758793.0
# Construction                                         830922.0  11264451.0
# Taxes on Products                                    830922.0  10774501.0
# Other services                                       830922.0   8059922.0
# Crops                                                830922.0   7962514.0
# Trade & repair services*                             154778.0   7763847.0
# Transport, storage, communication & services re...   830922.0   6818560.0
# Trade & repair services                              676144.0   5225900.0
# ...

# %%
#Top 5 Contributor of C1

gf1_c11=gf1_c11.iloc[0:5]
gf1_c11
# Out:
#                                                     2014-15_x   2014-15_y  \
# Sub Sectors
# Real estate, ownership of dwelling & profession...   830922.0  14740245.0
# Agriculture, forestry and fishing                    830922.0  14391809.0
# Trade, repair, hotels and restaurants                830922.0  13995159.0
# Manufacturing                                        830922.0  13758793.0
# Construction                                         830922.0  11264451.0
#
#                                                       Average
# Sub Sectors
# Real estate, ownership of dwelling & profession...  14.461049
# Agriculture, forestry and fishing                   14.119213
# Trade, repair, hotels and restaurants               13.730076
# Manufacturing                                       13.498187
# Construction                                        11.051090

# %%
#Plot the conribution of the sub-sectors as a percentage of the GSDP of C1

labels='Real estate','Agriculture','Trade','Manufacturing','Construction','Others'
size=[14.46,14.12,13.73,13.50,11.05,33.14]
fig1,mx=plt.subplots()
mx.pie(size,labels=labels,autopct='%1.2f',startangle=90)
mx.axis('equal')
plt.title("conribution of the sub-sectors as a percentage of the GSDP of C1")
plt.show()

# %%
#Dataframe for C2
gf1_c2=gf1.loc[gf1.Quantile=='c2']

# %%
gf1_c2
# Out:
#                   S.No._x                 Item_x  2014-15_x Quantile S.No._y  \
# State
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2       1
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2     1.1
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2     1.2
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2     1.3
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2     1.4
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2       2
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2   Total
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2       3
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2       4
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2       5
# Uttarakhand            17  Per Capita GSDP (Rs.)   153076.0       c2   Total
# ...

# %%
gf1_c22=gf1_c2.groupby('Sub Sectors').agg('sum')
gf1_c22
# Out:
#                                                     2014-15_x     2014-15_y
# Sub Sectors
# Agriculture, forestry and fishing                   1377243.0  7.589514e+07
# Air transport                                       1377243.0  6.598410e+05
# Communication & services related to broadcasting    1377243.0  9.428429e+06
# Construction                                        1377243.0  4.080140e+07
# Crops                                               1377243.0  4.796562e+07
# Electricity, gas, water supply & other utility ...  1377243.0  1.393690e+07
# Financial services                                  1377243.0  3.632185e+07
# Fishing and aquaculture                             1377243.0  2.700015e+06
# Forestry and logging                                1377243.0  5.827230e+06
# Gross State Domestic Product                        1377243.0  5.880566e+08
# Hotels & restaurants                                1377243.0  5.990151e+06
# ...

# %%
# Adding Percentage column
gf1_c22['Percentage']= (gf1_c22['2014-15_y']/5.880566e+08)*100
gf1_c22.sort_values('Percentage',ascending=False,inplace=True)
gf1_c22
# Out:
#                                                     2014-15_x     2014-15_y  \
# Sub Sectors
# Gross State Domestic Product                        1377243.0  5.880566e+08
# TOTAL GSVA at basic prices                          1377243.0  5.291204e+08
# Tertiary                                            1377243.0  2.788601e+08
# Secondary                                           1377243.0  1.639610e+08
# Manufacturing                                       1377243.0  1.092226e+08
# Real estate, ownership of dwelling & profession...  1377243.0  9.216986e+07
# Primary                                             1377243.0  8.629933e+07
# Agriculture, forestry and fishing                   1377243.0  7.589514e+07
# Taxes on Products                                   1377243.0  7.197214e+07
# Trade, repair, hotels and restaurants               1377243.0  6.129928e+07
# Trade & repair services                             1377243.0  5.530913e+07
# ...

# %%
# Drop out Rows which are not needed for further analysis

gf1_c22=gf1_c22.drop('Gross State Domestic Product',axis=0)
gf1_c22=gf1_c22.drop('TOTAL GSVA at basic prices',axis=0)
gf1_c22=gf1_c22.drop('Tertiary',axis=0)
gf1_c22=gf1_c22.drop('Secondary',axis=0)
gf1_c22=gf1_c22.drop('Primary',axis=0)
gf1_c22
# Out:
#                                                     2014-15_x     2014-15_y  \
# Sub Sectors
# Manufacturing                                       1377243.0  1.092226e+08
# Real estate, ownership of dwelling & profession...  1377243.0  9.216986e+07
# Agriculture, forestry and fishing                   1377243.0  7.589514e+07
# Taxes on Products                                   1377243.0  7.197214e+07
# Trade, repair, hotels and restaurants               1377243.0  6.129928e+07
# Trade & repair services                             1377243.0  5.530913e+07
# Crops                                               1377243.0  4.796562e+07
# Construction                                        1377243.0  4.080140e+07
# Other services                                      1377243.0  3.647238e+07
# Financial services                                  1377243.0  3.632185e+07
# Transport, storage, communication & services re...  1377243.0  3.378501e+07
# ...

# %%
#Top 6 contributer of C2

gf1_c22=gf1_c22.iloc[0:6]
gf1_c22
# Out:
#                                                     2014-15_x     2014-15_y  \
# Sub Sectors
# Manufacturing                                       1377243.0  1.092226e+08
# Real estate, ownership of dwelling & profession...  1377243.0  9.216986e+07
# Agriculture, forestry and fishing                   1377243.0  7.589514e+07
# Taxes on Products                                   1377243.0  7.197214e+07
# Trade, repair, hotels and restaurants               1377243.0  6.129928e+07
# Trade & repair services                             1377243.0  5.530913e+07
#
#                                                     Percentage
# Sub Sectors
# Manufacturing                                        18.573493
# Real estate, ownership of dwelling & profession...   15.673638
# Agriculture, forestry and fishing                    12.906094
# Taxes on Products                                    12.238982
# Trade, repair, hotels and restaurants                10.424045
# ...

# %%
#Plot the contribution of the sub-sectors as a percentage of the GSDP of C2
# Adding the value of Trade, repair, hotels and restaurants and Trade & repair services
labels = 'Manufacturing','Real estate','Agriculture','Taxes on Products','Trade','Others'
size=[18.62,15.71,12.83,12.26,19.86,20.73]
fig1,ax=plt.subplots()
ax.pie(size,labels=labels,autopct='%1.2f',startangle=90)
ax.axis('equal')
plt.title("contribution of the sub-sectors as a percentage of the GSDP of C2")
plt.show()

# %%
# Dataframe for C3
gf1_c3=gf1.loc[gf1.Quantile=='c3']

# %%
gf1_c3
# Out:
#                S.No._x                 Item_x  2014-15_x Quantile S.No._y  \
# State
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3       1
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3     1.1
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3     1.2
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3     1.3
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3     1.4
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3       2
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3   Total
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3       3
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3       4
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3       5
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3   Total
# Andhra_Pradesh      17  Per Capita GSDP (Rs.)   104977.0       c3       6
# ...

# %%
gf1_c333=gf1_c3.groupby('Sub Sectors').agg('sum')
gf1_c333
# Out:
#                                                     2014-15_x    2014-15_y
# Sub Sectors
# Agriculture, forestry and fishing                    691533.0   42226888.0
# Air transport                                        691533.0      58970.0
# Communication & services related to broadcasting     691533.0    3050206.0
# Construction                                         691533.0   15707921.0
# Crops                                                691533.0   23676317.0
# Electricity, gas, water supply & other utility ...   691533.0    4604774.0
# Financial services                                   691533.0    5766226.0
# Fishing and aquaculture                              691533.0    3368881.0
# Forestry and logging                                 691533.0    4045895.0
# Gross State Domestic Product                         691533.0  177966387.0
# Hotels & restaurants                                 691533.0    1291961.0
# ...

# %%
# Adding Percentage column
gf1_c333['Percentage']= (gf1_c333['2014-15_y']/177966387)*100
gf1_c333.sort_values('Percentage',ascending=False,inplace=True)
gf1_c333
# Out:
#                                                     2014-15_x    2014-15_y  \
# Sub Sectors
# Gross State Domestic Product                         691533.0  177966387.0
# TOTAL GSVA at basic prices                           691533.0  167623415.0
# Tertiary                                             691533.0   72209729.0
# Primary                                              691533.0   53062661.0
# Secondary                                            691533.0   42351025.0
# Agriculture, forestry and fishing                    691533.0   42226888.0
# Crops                                                691533.0   23676317.0
# Manufacturing                                        691533.0   22038331.0
# Trade, repair, hotels and restaurants                691533.0   17245309.0
# Taxes on Products                                    691533.0   17122953.0
# Real estate, ownership of dwelling & profession...   691533.0   16224118.0
# ...

# %%
# Drop out Rows which are not needed for further analysis

gf1_c333=gf1_c333.drop('Gross State Domestic Product',axis=0)
gf1_c333=gf1_c333.drop('TOTAL GSVA at basic prices',axis=0)
gf1_c333=gf1_c333.drop('Tertiary',axis=0)
gf1_c333=gf1_c333.drop('Secondary',axis=0)
gf1_c333=gf1_c333.drop('Primary',axis=0)
gf1_c333
# Out:
#                                                     2014-15_x   2014-15_y  \
# Sub Sectors
# Agriculture, forestry and fishing                    691533.0  42226888.0
# Crops                                                691533.0  23676317.0
# Manufacturing                                        691533.0  22038331.0
# Trade, repair, hotels and restaurants                691533.0  17245309.0
# Taxes on Products                                    691533.0  17122953.0
# Real estate, ownership of dwelling & profession...   691533.0  16224118.0
# Trade & repair services                              691533.0  15953349.0
# Construction                                         691533.0  15707921.0
# Other services                                       691533.0  12815417.0
# Transport, storage, communication & services re...   691533.0  12231484.0
# Livestock                                            691533.0  11135794.0
# ...

# %%
#Top 7 contributer of c3

gf1_c3333=gf1_c333.iloc[0:7]
gf1_c3333
# Out:
#                                                     2014-15_x   2014-15_y  \
# Sub Sectors
# Agriculture, forestry and fishing                    691533.0  42226888.0
# Crops                                                691533.0  23676317.0
# Manufacturing                                        691533.0  22038331.0
# Trade, repair, hotels and restaurants                691533.0  17245309.0
# Taxes on Products                                    691533.0  17122953.0
# Real estate, ownership of dwelling & profession...   691533.0  16224118.0
# Trade & repair services                              691533.0  15953349.0
#
#                                                     Percentage
# Sub Sectors
# Agriculture, forestry and fishing                    23.727451
# Crops                                                13.303814
# Manufacturing                                        12.383423
# Trade, repair, hotels and restaurants                 9.690206
# ...

# %%
#Plot the contribution of the sub-sectors as a percentage of the GSDP of C3
# Adding the value of Trade, repair, hotels and restaurants and Trade & repair services

labels = 'Agriculture','Crops','Manufacturing','Trade','Taxes on Products','Others'
size=[23.73,13.30,12.38,18.65,9.62,22.32]
fig1,ax=plt.subplots()
ax.pie(size,labels=labels,autopct='%1.2f',startangle=90)
ax.axis('equal')
plt.title("contribution of the sub-sectors as a percentage of the GSDP of C3")
plt.show()

# %%
# Dataframe for C4
gf1_c4=gf1.loc[gf1.Quantile=='c4']
gf1_c44=gf1_c4.groupby('Sub Sectors').agg('sum')
gf1_c44
# Out:
#                                                     2014-15_x    2014-15_y
# Sub Sectors
# Agriculture, forestry and fishing                    327547.0   56735044.0
# Air transport                                        327547.0     116154.0
# Communication & services related to broadcasting     327547.0    4462395.0
# Construction                                         327547.0   22775948.0
# Crops                                                327547.0   39331055.0
# Electricity, gas, water supply & other utility ...   327547.0    4310264.0
# Financial services                                   327547.0    7684498.0
# Fishing and aquaculture                              327547.0    1828960.0
# Forestry and logging                                 327547.0    3673623.0
# Gross State Domestic Product                         327547.0  233252066.0
# Hotels & restaurants                                 327547.0    1903356.0
# ...

# %%
# Adding Percentage column
gf1_c44['Percentage']= (gf1_c44['2014-15_y']/233252066)*100
gf1_c44.sort_values('Percentage',ascending=False,inplace=True)
gf1_c44
# Out:
#                                                     2014-15_x    2014-15_y  \
# Sub Sectors
# Gross State Domestic Product                         327547.0  233252066.0
# TOTAL GSVA at basic prices                           327547.0  219788780.0
# Tertiary                                             327547.0  104884072.0
# Primary                                              327547.0   62831463.0
# Agriculture, forestry and fishing                    327547.0   56735044.0
# Secondary                                            327547.0   52073244.0
# Crops                                                327547.0   39331055.0
# Trade, repair, hotels and restaurants                327547.0   27484595.0
# Trade & repair services                              327547.0   25581239.0
# Manufacturing                                        327547.0   24987032.0
# Real estate, ownership of dwelling & profession...   327547.0   24177534.0
# ...

# %%
# Drop out Rows which are not needed for further analysis

gf1_c44=gf1_c44.drop('Gross State Domestic Product',axis=0)
gf1_c44=gf1_c44.drop('TOTAL GSVA at basic prices',axis=0)
gf1_c44=gf1_c44.drop('Tertiary',axis=0)
gf1_c44=gf1_c44.drop('Secondary',axis=0)
gf1_c44=gf1_c44.drop('Primary',axis=0)
gf1_c44
# Out:
#                                                     2014-15_x   2014-15_y  \
# Sub Sectors
# Agriculture, forestry and fishing                    327547.0  56735044.0
# Crops                                                327547.0  39331055.0
# Trade, repair, hotels and restaurants                327547.0  27484595.0
# Trade & repair services                              327547.0  25581239.0
# Manufacturing                                        327547.0  24987032.0
# Real estate, ownership of dwelling & profession...   327547.0  24177534.0
# Construction                                         327547.0  22775948.0
# Taxes on Products                                    327547.0  21922888.0
# Transport, storage, communication & services re...   327547.0  16191800.0
# Other services                                       327547.0  15859015.0
# Public administration                                327547.0  13486630.0
# ...

# %%
#Top 7 contributer of c4

gf1_c44=gf1_c44.iloc[0:7]
gf1_c44
# Out:
#                                                     2014-15_x   2014-15_y  \
# Sub Sectors
# Agriculture, forestry and fishing                    327547.0  56735044.0
# Crops                                                327547.0  39331055.0
# Trade, repair, hotels and restaurants                327547.0  27484595.0
# Trade & repair services                              327547.0  25581239.0
# Manufacturing                                        327547.0  24987032.0
# Real estate, ownership of dwelling & profession...   327547.0  24177534.0
# Construction                                         327547.0  22775948.0
#
#                                                     Percentage
# Sub Sectors
# Agriculture, forestry and fishing                    24.323490
# Crops                                                16.862039
# Trade, repair, hotels and restaurants                11.783216
# Trade & repair services                              10.967208
# ...

# %%
#Plot the contribution of the sub-sectors as a percentage of the GSDP of C4
# Adding the value of Trade, repair, hotels and restaurants and Trade & repair services

labels = 'Agriculture','Crops','Trade','Manufacturing','Real estate','Others'
size=[24.32,16.86,22.74,10.71,10.36,15.03]
fig1,ax=plt.subplots()
ax.pie(size,labels=labels,autopct='%1.2f',startangle=90)
ax.axis('equal')
plt.title("contribution of the sub-sectors as a percentage of the GSDP of C4")
plt.show()

# %% [markdown]
# # Part 2

# %%
wf=pd.read_csv(r'C:/Users/Ashish Pandey/Downloads/rs_session243_au570_1.1.csv')
wf
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
#primary, upper primary and secondary for the year 2014-2015 for the states.

wf.set_index('Level of Education - State',inplace=True)
wf.transpose()
# Out:
# Level of Education - State   A & N Islands Andhra Pradesh Arunachal Pradesh  \
# Sl. No.                                  1              2                 3
# Primary - 2012-2013                   0.68           3.18             15.16
# Primary - 2014-2015                   1.21           4.35             10.89
# Primary - 2014-2015.1                 0.51           6.72             10.82
# Upper Primary - 2012-2013             1.23           3.36              7.47
# Upper Primary - 2013-2014             0.51           3.78              5.59
# Upper Primary - 2014-2015             1.69            5.2              6.71
# Secondary - 2012-2013                 5.56          12.72             12.93
# Secondary - 2013-2014                  7.2          12.65             14.49
# Secondary - 2014-2015                 9.87          15.71             17.11
# Senior Secondary - 2012-2013         14.14           0.35              5.11
# ...

# %%
#Dropping off unnecessary entries
wf=wf.drop('Primary - 2012-2013',axis=1)
wf=wf.drop('Primary - 2014-2015.1',axis=1)
wf=wf.drop('Upper Primary - 2012-2013',axis=1)
wf=wf.drop('Upper Primary - 2013-2014',axis=1)
wf=wf.drop('Secondary - 2012-2013',axis=1)
wf=wf.drop('Secondary - 2013-2014',axis=1)
wf=wf.drop('Senior Secondary - 2012-2013',axis=1)
wf=wf.drop('Senior Secondary - 2013-2014',axis=1)
wf=wf.drop('Senior Secondary - 2014-2015',axis=1)
wf=wf.drop('Sl. No.',axis=1)
wf=wf.drop('A & N Islands',axis=0)
wf=wf.drop('Chandigarh',axis=0)
wf=wf.drop('Daman & Diu',axis=0)
wf=wf.drop('Delhi',axis=0)
wf=wf.drop('Puducherry',axis=0)
wf
# Out:
#                             Primary - 2014-2015  Upper Primary - 2014-2015  \
# Level of Education - State
# Andhra Pradesh                             4.35                       5.20
# Arunachal Pradesh                         10.89                       6.71
# Assam                                      7.44                      10.51
# Bihar                                      2.09                       4.08
# Chhatisgarh                                1.42                       5.85
# Dadra & Nagar Haveli                       1.57                       4.02
# Goa                                        0.20                       0.07
# Gujarat                                    0.76                       6.41
# Haryana                                    0.41                       5.81
# Himachal Pradesh                           0.46                       0.87
# Jammu and Kashmir                          5.46                       5.44
# ...

# %%
df_gdp_per_cap
# Out:
#                   S.No.                   Item   2014-15 Quantile
# State
# Goa                  17  Per Capita GSDP (Rs.)  271793.0       c1
# Sikkim               17  Per Capita GSDP (Rs.)  240274.0       c1
# Haryana              17  Per Capita GSDP (Rs.)  164077.0       c1
# Kerala               17  Per Capita GSDP (Rs.)  154778.0       c1
# Uttarakhand          17  Per Capita GSDP (Rs.)  153076.0       c2
# Maharashtra          17  Per Capita GSDP (Rs.)  152853.0       c2
# Himachal_Pradesh     17  Per Capita GSDP (Rs.)  147330.0       c2
# Tamil_Nadu           17  Per Capita GSDP (Rs.)  146503.0       c2
# Karnataka            17  Per Capita GSDP (Rs.)  145141.0       c2
# Gujarat              17  Per Capita GSDP (Rs.)  141263.0       c2
# Telangana            17  Per Capita GSDP (Rs.)  139035.0       c2
# Punjab               17  Per Capita GSDP (Rs.)  126606.0       c2
# Arunachal_Pradesh    17  Per Capita GSDP (Rs.)  112718.0       c2
# ...

# %%
wf1=pd.concat([wf, df_gdp_per_cap],join='inner', axis=1, sort=False)

# %%
wf1
# Out:
#              Primary - 2014-2015  Upper Primary - 2014-2015  \
# Assam                       7.44                      10.51
# Bihar                       2.09                       4.08
# Goa                         0.20                       0.07
# Gujarat                     0.76                       6.41
# Haryana                     0.41                       5.81
# Jharkhand                   6.41                       8.99
# Karnataka                   2.32                       3.85
# Kerala                       NaN                        NaN
# Maharashtra                 0.55                       1.79
# Manipur                    18.00                       4.20
# Meghalaya                  10.34                       6.52
# Mizoram                    12.96                       4.78
# Nagaland                   19.41                       7.92
# Odisha                      2.94                       3.81
# Punjab                      1.29                       3.22
# ...

# %%
wf1=wf1.drop('S.No.',axis=1)
wf1=wf1.drop('Item',axis=1)
wf1=wf1.drop('Quantile',axis=1)
wf1
# Out:
#              Primary - 2014-2015  Upper Primary - 2014-2015  \
# Assam                       7.44                      10.51
# Bihar                       2.09                       4.08
# Goa                         0.20                       0.07
# Gujarat                     0.76                       6.41
# Haryana                     0.41                       5.81
# Jharkhand                   6.41                       8.99
# Karnataka                   2.32                       3.85
# Kerala                       NaN                        NaN
# Maharashtra                 0.55                       1.79
# Manipur                    18.00                       4.20
# Meghalaya                  10.34                       6.52
# Mizoram                    12.96                       4.78
# Nagaland                   19.41                       7.92
# Odisha                      2.94                       3.81
# Punjab                      1.29                       3.22
# ...

# %%
#Replacing NANS by Mean value
wf1.loc[np.isnan(wf1['Primary - 2014-2015']),['Primary - 2014-2015']]= wf1['Primary - 2014-2015'].mean()
wf1.loc[np.isnan(wf1['Upper Primary - 2014-2015']),['Upper Primary - 2014-2015']]= wf1['Upper Primary - 2014-2015'].mean()

# %%
wf1
# Out:
#              Primary - 2014-2015  Upper Primary - 2014-2015  \
# Assam                   7.440000                  10.510000
# Bihar                   2.090000                   4.080000
# Goa                     0.200000                   0.070000
# Gujarat                 0.760000                   6.410000
# Haryana                 0.410000                   5.810000
# Jharkhand               6.410000                   8.990000
# Karnataka               2.320000                   3.850000
# Kerala                  5.970556                   4.493889
# Maharashtra             0.550000                   1.790000
# Manipur                18.000000                   4.200000
# Meghalaya              10.340000                   6.520000
# Mizoram                12.960000                   4.780000
# Nagaland               19.410000                   7.920000
# Odisha                  2.940000                   3.810000
# Punjab                  1.290000                   3.220000
# ...

# %%
#correlation of GDP per capita with dropout rates in education

cor_matrix = wf1.corr()
round(df,3)
cor_matrix

plt.figure(figsize=(10,8))

#heatmap
sns.heatmap(cor_matrix, cmap="YlGnBu", annot=True)
plt.show()
